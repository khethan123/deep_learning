# %% [markdown]
# <del>delete this text</del><br>
# ~delete this text~
#
# <!-- The below part does not work in colab -->
# <div class='alert alert-block alert-info'> <i class="fas fa-lightbulb"></i>
# <b>Tip:</b> Use blue boxes for tips and notes.</div>
#
#
# <div class="alert alert-block alert-warning"><i class="fa fa-exclamation-triangle"></i>
# <b>Example:</b> Use yellow boxes for examples that are not inside code cells,
# or use for mathematical formulas if needed.
# Typically also used to display warning messages.
# </div>
#
# <i class="fa fa-cog fa-spin fa-1x fa-fw"></i>
# <div class="alert alert-block alert-success">
# <b>Success:</b> This alert box indicates a successful or positive action.
# </div>
#
# > <div class="alert alert-block alert-danger">
# <b>EXAMPLE:</b> Copy this entire line and paste it into the "markdown" section.
# </div>
#
# <!-- The below works only in colab. You can't enter values in jupyter markdown -->
# <div class="input-group margin-bottom-sm">
#   <span class="input-group-addon"><i class="fa fa-envelope-o fa-fw"></i></span>
#   <input class="form-control" type="text" placeholder="Email address">
# </div>
# <div class="input-group">
#   <span class="input-group-addon"><i class="fa fa-key fa-fw"></i></span>
#   <input class="form-control" type="password" placeholder="Password">
# </div>

# %%
# %%html
# <style>
#     .blue {
#         background-color: #0074D9;
#     }
#     .green {
#         background-color: #2ECC40;
#     }
# </style>
#
# <div class="blue">
#     This markdown cell is blue.
# </div>
#
# <div class="green">
#     This markdown cell is green.
# </div>
#
# <!-- this works everywhere -->
# Out:
# <style>
#     .blue {
#         background-color: #0074D9;
#     }
#     .green {
#         background-color: #2ECC40;
#     }
# </style>
#
# <div class="blue">
#     This markdown cell is blue.
# </div>
#
# <div class="green">
#     This markdown cell is green.
# </div>
#
# <!-- this works everywhere -->

# %% [markdown]
# <!-- this does not work in colab -->
# <a id="table"></a>
# <h1 style="background-color:pink;color:purple;font-family:monospace;font-size:350%;text-align:center;">Table Of Content</h1>
#
# * [1. IMPORTING LIBRARIES](#1)
# * [2. LOADING DATASET](#2)
#
#
# <p style="padding:10px;background-color:purple;margin:0;color:white;font-family:verdana;font-size:200%;text-align:center;border-radius: 8px ;overflow:hidden;font-weight:250">IMPORTING LIBRARIES</p>

# %% [markdown]
# <!-- this styling in h1 does not work in colab but the below one works. -->
#
# <h1 style="font-family:monospace;"> <center>📚 Create Better &amp; Beautiful Notebooks : The Tutorial 📚</center> </h1>
# <p><center><font color="#159364" face="cursive">Strive for Excellence, Not Perfection</center></p>
#
# ***

# %% [markdown]
# <cite>This is how to use citation</cite>
#
# <!-- div elements don't work in colab -->
# <div style="font-family:Calibri;">
#     Font-Family: Verdana, Cursive<br>
#     Colors Used: ['crimson', 'orange', #202EF9, #FE1C0A, #159364]<br>
#     Emoji Used: [📚, 📌, 😃, 💬, 🎖, 📎, 🏆, 🗣, 🔭, 🌈, 💭, ⏳, 🙌🏻]<br>
#
# </div>
#
# <!-- code element's styling does not work in colab -->
# <code style="background:yellow;color:black">Useful for highlighting to grab the attention of the reader towards certain points.</code>
#
# <p style="background:black">
# <code style="background:pink;color:purple">C:\Users\YOUR_USERNAME> pip3 install roughviz
# </code>
# </p>
#
# <!-- we can't change the background color in colab -->
# <code><font color="darkred" bgcolor="#def28d">C:\Users\YOUR_USERNAME> pip3 install roughviz
# </code>

# %% [markdown]
# <!-- works in everything -->
# <nav>
# <a href=”https://www.google.com">LinkedIn</a> |
# <a href=”/css/”>Github</a> |
# <a href=”/js/”>Medium</a> |
# </nav>

# %% [markdown]
# <!-- most of things don't work in colab -->
# <p style="font-size:15px; font-family:verdana; line-height: 1.7em">This notebook is created for people who want to make their notebooks look <span style="color:crimson;">āesthetic</span> and more pleasing to the viewer. We are <span style="color:gray;">not</span> going to solve any machine learning problem in this notebook (you can check my other notebooks for ML and EDA). We will only focus on the <span style="color:brown;">HTML &amp; Markdown</span> to make your notebooks looks prettier and beutiful 🙌🏻 .</p><br>
#
# <div style="font-size:15px; font-family:verdana;">By the end of this notebook you will be able to:<br><br>
# <ol>
#     <li>Beautifully format your notebooks.</li>
#     <li>Learn how to use HTML and Markdown in kaggle notebooks.</li>
#     <li>Learn some good quotes.</li>
# </ol>
# </div>
# <br>
#
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana; line-height: 1.7em;">
#     📌 &nbsp; Please keep in mind that, I am a beginner and on my learning journey as most of you. I just want to share something that will be useful for many kagglers working hard on their notebooks. If you find this notebook useful in anyway, please upvote it so that it can reach a bigger audience. You can share it with your fellow kagglers.
# </div>
# <br>
#
# ><p style="font-size:16px; color:#159364; font-family:verdana;">💬 Finally, I would like to take this opportunity to remind everyone to be <code>kind</code>, <code>just</code> and <code>mindful</code>😃</p>

# %% [markdown]
# <!-- works in everything, this is just to link cells within a notebook -->
# <h1 style="font-family:verdana;">
#     <center> Simple Markdown Links
#         <a class="anchor-link" href="">¶</a>
#     </center>
# </h1>

# %% [markdown]
# <div style="font-family:verdana; word-spacing:1.5px;">
#     <h1>
#         2.2 Change Font Family, Font Color, and Font Size
#         <a class="anchor-link" href="https://www.kaggle.com/shubhamksingh/formatting-notebooks-tutorial-html-markdown/notebook#family">¶</a>
#     </h1>
#     <p style="line-height:1.7em;">
#         In this section, we will learn how to change font-family, font-color, and font-size.
#         <ol>
#             <li>
#                 <b>Change Font Family</b>
#             </li>
#             <ul>
#                 <li>
#                     To change the font-family, first you should surround your text in a html tag such as <code>span</code>, <code>p</code> and <code>div</code> and then you have to add the css <code>style</code> property inside the html tag. After this you can change the family of font by <code>font-family</code> property. Lets look at an example to make sense of all this:<br><br>
#                     &lt;span style="font-family:cursive;"&gt; Love for all, Hatred for none &lt;/span&gt;
#                     <br><br>
#                     <span style="font-family:cursive;">Love for all, Hatred for none</span>
#                 </li>
#             </ul>
#             <br>
#             <li>
#                 <b>Change Font Color</b>
#             </li>
#             <ul>
#                 <li>
#                     To change the font-color, first you should surround your text in a html tag such as <code>span</code>, <code>p</code> and <code>div</code> and then you have to add the css <code>style</code> property inside the html tag. After this you can change the color of font by <code>color</code> property. Lets look at an example to make sense of all this:<br><br>
#                     &lt;span style="color:crimson;"&gt; Doubt kills more dreams than failure ever will. &lt;/span&gt;
#                     <br><br>
#                     <span style="color:#159364;">Doubt kills more dreams than failure ever will.</span>
#                 </li>
#             </ul>
#             <li>
#                 <b>Change Font Size</b>
#             </li>
#             <ul>
#                 <li>
#                     To change the font-size, first you should surround your text in a html tag such as <code>span</code>, <code>p</code> and <code>div</code> and then you have to add the css <code>style</code> property inside the html tag. After this you can change the size of font by <code>font-size</code> property. Lets look at an example to make sense of all this:<br><br>
#                     &lt;span style="font-size:18px;"&gt; Find peace in the journey. &lt;/span&gt;
#                     <br><br>
#                     <span style="font-size:18px;">Find peace in the journey.</span>
#                 </li>
#             </ul>
#         </ol>
#     </p>
# </div>
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana;">
#     📌 <b>Line Break and Whitespaces:</b><br><br>You can add a line-break by html break tag <code>&lt;br&gt;</code> and you can add more whitespaces by <code>&amp;nbsp;</code>
# </div>

# %% [markdown]
# <div style="font-family:verdana; word-spacing:1.5px;">
#     <h1>
#         2.3 Callout 🗣
#         <a class="anchor-link" href="">¶</a>
#     </h1>
#     <p style="line-height:1.7em;">
#         You can create a callout if you want to call out the <span style="color:crimson;">attention of your reader</span> to something important. It is a great way to express key points of any topic in your notebook.<br>
#         To create a callout 💭, follow these steps:<br>
#     <ol>
#         <li>
#             Create a <code>div</code> tag: &lt;div&gt; &lt;/div&gt;
#         </li>
#         <li>
#             create a <code>class</code> attribute inside the dive tag and give it a value of <code>"alert alert-block alert-info"</code>
#         </li>
#     </ol>
#     Write whatever you want inside the <code>div</code> tag and you are good to go.<br><br>Lets look at an example:<br>
#     <pre>&lt;div class="alert alert-block alert-info"&gt; 📌 Please note that class="alert alert-block alert-info" is a pre-defined class by kaggle and we are simply using it in our notebook.&lt;/div&gt;</pre>
#     becomes:
#     </p>
# </div>
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana;">
#     📌 Please note that class="alert alert-block alert-info" is a pre-defined class by kaggle and we are simply using it in our notebook.
# </div>

# %% [markdown]
# <div style="font-family:verdana; word-spacing:1.5px;">
#     <h1>
#         2.5 Make Beautiful Text Box
#         <a class="anchor-link" href="">¶</a>
#     </h1>
#     <p style="line-height:1.7em;">
#         This is similar to Callout, but the big difference is that this time we are <span style="color:crimson">taking control</span> and we will be designing the text box for important messages. So without any hassle, lets just get into it:<br><br>
#         By far, we have learnt a lot about using <span style="color:crimson;">html markdown</span> in our notebook. We will just add more knowledge to that understanding to create a textbox of our imagination.
#     <ol>
#         <li>
#             Simply create a <code>p</code> tag inside a <code>div</code> tag.
#         </li>
#         <li>
#             Write your heart out in the paragraph <code>p</code> tag.
#         </li>
#         <li>
#             Finally, the most important thing is the CSS styling in our html tags.
#         </li>
#     </ol>
#     <br>
#     Lets take a look at this example:<br>
#     <pre>&lt;div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px"&gt;<br>
# &lt;p style="padding: 10px;
#               color:white;"&gt;<br>
#               All that is gold does not glitter,Not all those who wander are lost;The old that is strong does not wither,Deep roots are not reached by the frost.
# &lt;/p&gt;
# &lt;/div&gt;</pre>
#     <br>
#     Will Become:<br><br>
#     <div style="color:white;
#     display:fill;
#            border-radius:3px;
#            background-color:#f2f2eb;;
#            font-size:110%;
#            font-family:monospace;
#            letter-spacing:0.5px">
#         <p style="padding: 10px;
#               color:#f958a9;">
#             All that is gold does not glitter,Not all those who wander are lost;The old that is strong does not wither,Deep roots are not reached by the frost.
#         </p>
#     </div>
#     </p>
# </div>
